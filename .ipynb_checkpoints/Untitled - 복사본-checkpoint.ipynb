# %%
import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats

# %matplotlib inline
plt.style.use('ggplot')

# %%
train = pd.read_csv('data/bike_test.csv')
train.head()
# Out:
#               datetime  season  holiday  workingday  weather   temp   atemp  \
# 0  2011-01-20 00:00:00       1        0           1        1  10.66  11.365
# 1  2011-01-20 01:00:00       1        0           1        1  10.66  13.635
# 2  2011-01-20 02:00:00       1        0           1        1  10.66  13.635
# 3  2011-01-20 03:00:00       1        0           1        1  10.66  12.880
# 4  2011-01-20 04:00:00       1        0           1        1  10.66  12.880
#
#    humidity  windspeed
# 0        56    26.0027
# 1        56     0.0000
# 2        56     0.0000
# 3        56    11.0014
# 4        56    11.0014

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6493 entries, 0 to 6492
# Data columns (total 9 columns):
# datetime      6493 non-null object
# season        6493 non-null int64
# holiday       6493 non-null int64
# workingday    6493 non-null int64
# weather       6493 non-null int64
# temp          6493 non-null float64
# atemp         6493 non-null float64
# humidity      6493 non-null int64
# windspeed     6493 non-null float64
# dtypes: float64(3), int64(5), object(1)
# memory usage: 456.7+ KB

# %%
train['datetime'] = pd.to_datetime(train['datetime'])

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6493 entries, 0 to 6492
# Data columns (total 9 columns):
# datetime      6493 non-null datetime64[ns]
# season        6493 non-null int64
# holiday       6493 non-null int64
# workingday    6493 non-null int64
# weather       6493 non-null int64
# temp          6493 non-null float64
# atemp         6493 non-null float64
# humidity      6493 non-null int64
# windspeed     6493 non-null float64
# dtypes: datetime64[ns](1), float64(3), int64(5)
# memory usage: 456.7 KB

# %%
datetime = train['datetime']
datetime.head()
# Out:
# 0   2011-01-20 00:00:00
# 1   2011-01-20 01:00:00
# 2   2011-01-20 02:00:00
# 3   2011-01-20 03:00:00
# 4   2011-01-20 04:00:00
# Name: datetime, dtype: datetime64[ns]

# %%
train['year']=datetime.dt.year
train['month']=datetime.dt.month
train['day']=datetime.dt.day
train['hour']=datetime.dt.hour
train['minute']=datetime.dt.minute
train['second']=datetime.dt.second
train.head()
# Out:
#              datetime  season  holiday  workingday  weather   temp   atemp  \
# 0 2011-01-20 00:00:00       1        0           1        1  10.66  11.365
# 1 2011-01-20 01:00:00       1        0           1        1  10.66  13.635
# 2 2011-01-20 02:00:00       1        0           1        1  10.66  13.635
# 3 2011-01-20 03:00:00       1        0           1        1  10.66  12.880
# 4 2011-01-20 04:00:00       1        0           1        1  10.66  12.880
#
#    humidity  windspeed  year  month  day  hour  minute  second
# 0        56    26.0027  2011      1   20     0       0       0
# 1        56     0.0000  2011      1   20     1       0       0
# 2        56     0.0000  2011      1   20     2       0       0
# 3        56    11.0014  2011      1   20     3       0       0
# 4        56    11.0014  2011      1   20     4       0       0

# %%
sns.barplot(data=train,x='year',y='count')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-8-6f82c82581c1> in <module>()
# ----> 1 sns.barplot(data=train,x='year',y='count')
#
# C:\ai\python\anaconda3\lib\site-packages\seaborn\categorical.py in barplot(x, y, hue, data, order, hue_order, estimator, ci, n_boot, units, orient, color, palette, saturation, errcolor, errwidth, capsize, dodge, ax, **kwargs)
#    3147                           estimator, ci, n_boot, units,
#    3148                           orient, color, palette, saturation,
# -> 3149                           errcolor, errwidth, capsize, dodge)
#    3150
#    3151     if ax is None:
#
# C:\ai\python\anaconda3\lib\site-packages\seaborn\categorical.py in __init__(self, x, y, hue, data, order, hue_order, estimator, ci, n_boot, units, orient, color, palette, saturation, errcolor, errwidth, capsize, dodge)
#    1605         """Initialize the plotter."""
#    1606         self.establish_variables(x, y, hue, data, orient,
# -> 1607                                  order, hue_order, units)
#    1608         self.establish_colors(color, palette, saturation)
#    1609         self.estimate_statistic(estimator, ci, n_boot)
#
# C:\ai\python\anaconda3\lib\site-packages\seaborn\categorical.py in establish_variables(self, x, y, hue, data, orient, order, hue_order, units)
#     153                 if isinstance(input, string_types):
#     154                     err = "Could not interpret input '{}'".format(input)
# --> 155                     raise ValueError(err)
#     156
#     157             # Figure out the plotting orientation
#
# ValueError: Could not interpret input 'count'

# %%
sns.barplot(data=train,x='month',y='count')

# %%
sns.barplot(data=train,x='day',y='count')

# %%
sns.barplot(data=train,x='hour',y='count')

# %%
train['dayofweek']=datetime.dt.dayofweek
train
# Out:
#                 datetime  season  holiday  workingday  weather   temp   atemp  \
# 0    2011-01-20 00:00:00       1        0           1        1  10.66  11.365
# 1    2011-01-20 01:00:00       1        0           1        1  10.66  13.635
# 2    2011-01-20 02:00:00       1        0           1        1  10.66  13.635
# 3    2011-01-20 03:00:00       1        0           1        1  10.66  12.880
# 4    2011-01-20 04:00:00       1        0           1        1  10.66  12.880
# ...                  ...     ...      ...         ...      ...    ...     ...
# 6488 2012-12-31 19:00:00       1        0           1        2  10.66  12.880
# 6489 2012-12-31 20:00:00       1        0           1        2  10.66  12.880
# 6490 2012-12-31 21:00:00       1        0           1        1  10.66  12.880
# 6491 2012-12-31 22:00:00       1        0           1        1  10.66  13.635
# 6492 2012-12-31 23:00:00       1        0           1        1  10.66  13.635
#
#       humidity  windspeed  year  month  day  hour  minute  second  dayofweek
# 0           56    26.0027  2011      1   20     0       0       0          3
# 1           56     0.0000  2011      1   20     1       0       0          3
# 2           56     0.0000  2011      1   20     2       0       0          3
# 3           56    11.0014  2011      1   20     3       0       0          3
# 4           56    11.0014  2011      1   20     4       0       0          3
# ...        ...        ...   ...    ...  ...   ...     ...     ...        ...
# 6488        60    11.0014  2012     12   31    19       0       0          0
# 6489        60    11.0014  2012     12   31    20       0       0          0
# 6490        60    11.0014  2012     12   31    21       0       0          0
# 6491        56     8.9981  2012     12   31    22       0       0          0
# 6492        65     8.9981  2012     12   31    23       0       0          0
#
# [6493 rows x 16 columns]

# %%
plt.figure(figsize=(30,10))
sns.pointplot(data=train, x="hour", y="count", hue='workingday')

# %%
plt.figure(figsize=(30,10))
sns.pointplot(data=train, x="hour", y="count", hue='dayofweek')

# %%
plt.figure(figsize=(30,10))
sns.pointplot(data=train, x="hour", y="count", hue='weather')

# %%
plt.figure(figsize=(30,10))
sns.pointplot(data=train, x="hour", y="count", hue='season')

# %%
plt.figure(figsize=(30,10))
sns.regplot(data=train, x="humidity", y="count")

# %%
plt.figure(figsize=(30,10))
sns.regplot(data=train, x="windspeed", y="count")

# %%
fig, ax = plt.subplots()
fig.set_size_inches(30,30)
sns.heatmap(train.corr(), annot=True, cmap="RdBu_r", annot_kws={'size':20},linewidths=0.5)

# %%
q1 = np.percentile(train['count'],25)
q3 = np.percentile(train['count'],75)

# %%
iqr = q3-q1
iqr

# %%
train_without_liers = train[(train['count']>=q1-(1.5*iqr))&(train['count']<=q3+(1.5*iqr))]

# %%
print(train.shape)
print(train_without_liers.shape)

# %%
train=train_without_liers

# %%
plt.figure(figsize=(30,10))
sns.distplot(train['count'])

# %%
train['count'] = np.log1p(train['count'])
plt.figure(figsize=(30,10))
sns.distplot(train['count'])

# %%
y=train['count']
y.head()

# %%
X = train

# %%
X.pop('datetime')
# Out:
# 0      2011-01-20 00:00:00
# 1      2011-01-20 01:00:00
# 2      2011-01-20 02:00:00
# 3      2011-01-20 03:00:00
# 4      2011-01-20 04:00:00
#                ...
# 6488   2012-12-31 19:00:00
# 6489   2012-12-31 20:00:00
# 6490   2012-12-31 21:00:00
# 6491   2012-12-31 22:00:00
# 6492   2012-12-31 23:00:00
# Name: datetime, Length: 6493, dtype: datetime64[ns]

# %%
X.pop('day')
X.pop('minute')
X.pop('second')
# Out:
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 6488    0
# 6489    0
# 6490    0
# 6491    0
# 6492    0
# Name: second, Length: 6493, dtype: int64

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.2)

# %%
from sklearn.linear_model import LinearRegression
linear_regression = LinearRegression()
linear_regression.fit(X_train,y_train)

# %%
pred = linear_regression.predict(X_train)

# %%
linear_regression.score(X_train,y_train)

# %%
from sklearn.metrics import mean_squared_error
print("mse : ",mean_squared_error(pred,y_train))

# %%
pred = linear_regression.predict(X_test)
mean_squared_error(pred,y_test)

# %%
linear_regression.score(X_test,y_test)

# %%
=pd.read_csv('data/bike_test.csv')
